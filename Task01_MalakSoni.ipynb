# %%
#importing libraries-created by Malak Soni 7778995495
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\malak\Downloads\TASK01_DATAANALYSIS_MalakSoni.csv"

# %%
#loading my dataset which i have created by myself using diffrent certified resources
data = pd.read_csv(path)

# %%
data
#I got data from 2020-2024 but in 2020 i only got the Bank's data so I prefer to go for 2022-24 for only UPI APPS
# Out:
#             DATE                       UPI APP VOL(Million)     VOL(Cr)  \
# 0     31/01/2022     Airtel Payments Bank Apps         8.53  204745.00%
# 1     31/01/2022            Allahabad Bank App         0.02     736.00%
# 2     31/01/2022                    Amazon Pay         73.5  672966.00%
# 3     31/01/2022     AU Small Finance Bank App         0.23    8115.00%
# 4     31/01/2022                Axis Bank Apps         6.78  105877.00%
# ...          ...                           ...          ...         ...
# 1332  31/03/2024                       TataNeu         0.25       25.46
# 1333  31/03/2024            Bank of India Apps          0.2       78.81
# 1334  31/03/2024  Standard Chartered Bank Apps         0.19      115.77
# 1335  31/03/2024                         Dhani         0.19        5.98
# 1336  31/03/2024                 UCO Bank Apps         0.18       56.32
#
#        Column6   Column7 Column8 Column9 Column10  Column11 Column12  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337 entries, 0 to 1336
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATE          1337 non-null   object
#  1   UPI APP       1337 non-null   object
#  2   VOL(Million)  1337 non-null   object
#  3   VOL(Cr)       1337 non-null   object
#  4   Column6       1337 non-null   object
#  5   Column7       1337 non-null   object
#  6   Column8       1337 non-null   object
#  7   Column9       1337 non-null   object
#  8   Column10      1241 non-null   object
#  9   Column11      1241 non-null   object
#  10  Column12      1337 non-null   object
#  11  Column13      1337 non-null   object
#  12  Unnamed: 12   0 non-null      float64
# dtypes: float64(1), object(12)
# memory usage: 135.9+ KB

# %%
data.head()
# Out:
#          DATE                    UPI APP VOL(Million)     VOL(Cr)   Column6  \
# 0  31/01/2022  Airtel Payments Bank Apps         8.53  204745.00%         -
# 1  31/01/2022         Allahabad Bank App         0.02     736.00%         -
# 2  31/01/2022                 Amazon Pay         73.5  672966.00%         -
# 3  31/01/2022  AU Small Finance Bank App         0.23    8115.00%         -
# 4  31/01/2022             Axis Bank Apps         6.78  105877.00%  4047.00%
#
#     Column7 Column8 Column9 Column10  Column11 Column12  Column13  Unnamed: 12
# 0         -       -       -     4.69  2,682.32    13.22  4,729.77          NaN
# 1         -       -       -        -         -     0.02      7.36          NaN
# 2         -       -       -        -         -     73.5  6,729.66          NaN
# 3         -       -       -        -         -     0.23     81.15          NaN
# 4  3425.00%       -       -        -         -    47.25  1,093.02          NaN

# %%
data.tail()
# Out:
#             DATE                       UPI APP VOL(Million) VOL(Cr) Column6  \
# 1332  31/03/2024                       TataNeu         0.25   25.46       0
# 1333  31/03/2024            Bank of India Apps          0.2   78.81       0
# 1334  31/03/2024  Standard Chartered Bank Apps         0.19  115.77       0
# 1335  31/03/2024                         Dhani         0.19    5.98       0
# 1336  31/03/2024                 UCO Bank Apps         0.18   56.32       0
#
#      Column7 Column8 Column9 Column10 Column11 Column12 Column13  Unnamed: 12
# 1332       0       0       0        0        0     0.25    25.46          NaN
# 1333       0       0       0        0        0      0.2    78.81          NaN
# 1334       0       0    1.11        0        0     0.19   116.88          NaN
# 1335       0       0       0        0        0     0.19     5.98          NaN
# 1336       0       0       0        0        0     0.18    56.32          NaN

# %%
data.describe()
# Out:
#        Unnamed: 12
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
data.isnull().sum()
# Out:
# DATE               0
# UPI APP            0
# VOL(Million)       0
# VOL(Cr)            0
# Column6            0
# Column7            0
# Column8            0
# Column9            0
# Column10          96
# Column11          96
# Column12           0
# Column13           0
# Unnamed: 12     1337
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 1529

# %%
columns_to_drop = ['Column6', 'Column7', 'Column8', 'Column9', 'Column10', 'Column11', 'Column12', 'Column13', 'Unnamed: 12']
data.drop(columns=columns_to_drop, inplace=True)
#Why i deleted these columns is beacuse we are intrested to find Market analysis and these are just conversion of each other or it has Null values

# %%
data
#Date is needed beacuse refrence of time we can analize
#UPI APP will repeate every 40 or 50 rows same as date so we have to do something for that
#VOL(Million) Volume of transaction in that particular month Million
# Out:
#             DATE                       UPI APP VOL(Million)     VOL(Cr)
# 0     31/01/2022     Airtel Payments Bank Apps         8.53  204745.00%
# 1     31/01/2022            Allahabad Bank App         0.02     736.00%
# 2     31/01/2022                    Amazon Pay         73.5  672966.00%
# 3     31/01/2022     AU Small Finance Bank App         0.23    8115.00%
# 4     31/01/2022                Axis Bank Apps         6.78  105877.00%
# ...          ...                           ...          ...         ...
# 1332  31/03/2024                       TataNeu         0.25       25.46
# 1333  31/03/2024            Bank of India Apps          0.2       78.81
# 1334  31/03/2024  Standard Chartered Bank Apps         0.19      115.77
# 1335  31/03/2024                         Dhani         0.19        5.98
# 1336  31/03/2024                 UCO Bank Apps         0.18       56.32
#
# [1337 rows x 4 columns]

# %%
data.drop(columns=["VOL(Cr)"], inplace=True)
#we will go for million so we delete the Cr

# %%
data.isnull().sum()
#Okay No Null is there
# Out:
# DATE            0
# UPI APP         0
# VOL(Million)    0
# dtype: int64

# %%
data
# Out:
#             DATE                       UPI APP VOL(Million)
# 0     31/01/2022     Airtel Payments Bank Apps         8.53
# 1     31/01/2022            Allahabad Bank App         0.02
# 2     31/01/2022                    Amazon Pay         73.5
# 3     31/01/2022     AU Small Finance Bank App         0.23
# 4     31/01/2022                Axis Bank Apps         6.78
# ...          ...                           ...          ...
# 1332  31/03/2024                       TataNeu         0.25
# 1333  31/03/2024            Bank of India Apps          0.2
# 1334  31/03/2024  Standard Chartered Bank Apps         0.19
# 1335  31/03/2024                         Dhani         0.19
# 1336  31/03/2024                 UCO Bank Apps         0.18
#
# [1337 rows x 3 columns]

# %%
# Aggregate data by UPI APP
aggregated_data = data.groupby("UPI APP").agg({
    "VOL(Million)": "sum"  # Total transaction volume
}).reset_index()

# Create a new DataFrame with aggregated data
aggregated_df = pd.DataFrame(aggregated_data)
#We groupped our UPI APPS For creating a category

# %%
# Analyze the aggregated data
# transaction volumes for each UPI APP category
plt.figure(figsize=(180, 80))
plt.bar(aggregated_df['UPI APP'], aggregated_df['VOL(Million)'])
plt.xticks(rotation=90)
plt.xlabel('UPI App')
plt.ylabel('Total Transaction Volume (Million)')
plt.title('Total Transaction Volume by UPI App')
plt.show()

# %%
# Remove commas from the 'VOL(Million)' column in your 'data' DataFrame beacuse there can be error
data['VOL(Million)'] = data['VOL(Million)'].str.replace(',', '')

# Convert the 'VOL(Million)' column to float
data['VOL(Million)'] = data['VOL(Million)'].astype(float)

# Aggregate data by UPI APP
aggregated_data = data.groupby("UPI APP").agg({
    "VOL(Million)": "sum" 
}).reset_index()

# Sort aggregated data by transaction volumes in descending order
aggregated_df_sorted = aggregated_data.sort_values(by='VOL(Million)', ascending=False)

# %%
# Plot the Bar Chart of Total Transaction ****Volume v/s UPI App*****
plt.figure(figsize=(48, 36))
plt.bar(aggregated_df_sorted['UPI APP'], aggregated_df_sorted['VOL(Million)'])
plt.xticks(rotation=45)
plt.xlabel('UPI App')
plt.ylabel('Total Transaction Volume (Million)')
plt.title('Total Transaction Volume by UPI App')
plt.tight_layout()
plt.show()

# %%
data['VOL(Million)'] = data['VOL(Million)'].astype(float)

# Grouping based on 'UPI APP' and 'DATE'
# Assuming every 50 or more rows have the same 'DATE'
# You may need to adjust the group size based on your actual data
group_size = 50
data['Group'] = (data.index // group_size) + 1

# Aggregate data by 'UPI APP', 'DATE', and 'Group'
aggregated_data = data.groupby(["UPI APP", "DATE", "Group"]).agg({
    "VOL(Million)": "sum"  # Total transaction volume
}).reset_index()

# Sort aggregated data by 'DATE'
aggregated_data_sorted = aggregated_data.sort_values(by='DATE')

# Create a list of unique UPI Apps
unique_apps = aggregated_data_sorted['UPI APP'].unique()

# Plot market capture for each UPI App over time
plt.figure(figsize=(12, 8))
for app in unique_apps:
    app_data = aggregated_data_sorted[aggregated_data_sorted['UPI APP'] == app]
    plt.plot(app_data['DATE'], app_data['VOL(Million)'], label=app)

plt.xlabel('Date')
plt.ylabel('Total Transaction Volume (Million)')
plt.title('Market Capture of UPI Apps over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\malak\AppData\Local\Temp\ipykernel_8928\4090835157.py:31: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
colors = {'PhonePe': 'blue', 'Google Pay': 'green', 'Paytm': 'red'}

# Plot market capture for each UPI App over time
#For conviniance i highlighted three of our highest category in diff col...
plt.figure(figsize=(12, 8))
for app in unique_apps:
    app_data = aggregated_data_sorted[aggregated_data_sorted['UPI APP'] == app]
    if app in colors:
        plt.plot(app_data['DATE'], app_data['VOL(Million)'], label=app, color=colors[app])
    else:
        # Use default color for other apps
        plt.plot(app_data['DATE'], app_data['VOL(Million)'], label=app)

plt.xlabel('Date')
plt.ylabel('Total Transaction Volume (Million)')
plt.title('Market Capture of UPI Apps over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\malak\AppData\Local\Temp\ipykernel_8928\2785332592.py:18: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
phonepe_data = data[data['UPI APP'] == 'PhonePe']['VOL(Million)'].sum()
googlepay_data = data[data['UPI APP'] == 'Google Pay']['VOL(Million)'].sum()
paytm_data = data[data['UPI APP'] == 'Paytm']['VOL(Million)'].sum()

# Calculate total transaction volume for all three apps
total_volume = phonepe_data + googlepay_data + paytm_data

# Calculate market share for each app
phonepe_share = (phonepe_data / total_volume) * 100
googlepay_share = (googlepay_data / total_volume) * 100
paytm_share = (paytm_data / total_volume) * 100

# Create labels and sizes for the pie chart
labels = ['PhonePe', 'Google Pay', 'Paytm']
sizes = [phonepe_share, googlepay_share, paytm_share]

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Market Share of PhonePe, Google Pay, and Paytm,Created By "Malak Soni"')
plt.axis('equal')  
plt.show()
#This pie chart is to Analize  market share between three of them we can also check for all but i think this is enough
